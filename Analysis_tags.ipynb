# %% [markdown]
# <a href="https://colab.research.google.com/github/willsantim/Grouplens-MovieLens-Latest-Datasets-Small/blob/main/Analysis_tags.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **WILLIAM SANTIM** - RA: **082220033**
# CURSO: **ENGENHARIA DE COMPUTAÇÃO**
#
# ELETIVA II - AMBIENTES INTELIGENTES
# ATIVIDADE N1 - 1° BIMESTRE
#
# **ANÁLISE DA TABELA: TAGS**

# %% [markdown]
# IMPORTANDO BIBLIOTECAS:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Explorando o Dataset
# Dataset SMALL retirado do seguinte link: https://grouplens.org/datasets/movielens/

# %% [markdown]
# 1.1 - Importando o Dataset

# %%
df = pd.read_csv('/content/tags.csv')

# %%
df.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
df.columns = ['ID Usuario', 'ID Filme', 'Tag', 'Data e Hora da Tag']
df.head()
# Out:
#    ID Usuario  ID Filme              Tag  Data e Hora da Tag
# 0           2     60756            funny          1445714994
# 1           2     60756  Highly quotable          1445714996
# 2           2     60756     will ferrell          1445714992
# 3           2     89774     Boxing story          1445715207
# 4           2     89774              MMA          1445715200

# %% [markdown]
# 1.2 - Informações básicas do dataset

# %%
print(f'O dataset possui {df.shape[0]} exemplos/amostras/linhas e {df.shape[1]} atributos/variáveis/colunas.')
# Out:
# O dataset possui 3683 exemplos/amostras/linhas e 4 atributos/variáveis/colunas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID Usuario          3683 non-null   int64
#  1   ID Filme            3683 non-null   int64
#  2   Tag                 3683 non-null   object
#  3   Data e Hora da Tag  3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB

# %% [markdown]
# Corrigindo os dados da coluna "Data e Hora da Tag"

# %%
df['Data e Hora da Tag'] = pd.to_datetime(df['Data e Hora da Tag'], unit='s')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID Usuario          3683 non-null   int64
#  1   ID Filme            3683 non-null   int64
#  2   Tag                 3683 non-null   object
#  3   Data e Hora da Tag  3683 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 115.2+ KB

# %%
df.head()
# Out:
#    ID Usuario  ID Filme              Tag  Data e Hora da Tag
# 0           2     60756            funny 2015-10-24 19:29:54
# 1           2     60756  Highly quotable 2015-10-24 19:29:56
# 2           2     60756     will ferrell 2015-10-24 19:29:52
# 3           2     89774     Boxing story 2015-10-24 19:33:27
# 4           2     89774              MMA 2015-10-24 19:33:20

# %%
df.describe()
# Out:
#         ID Usuario       ID Filme             Data e Hora da Tag
# count  3683.000000    3683.000000                           3683
# mean    431.149335   27252.013576  2011-10-31 03:32:46.823784960
# min       2.000000       1.000000            2006-01-13 19:09:12
# 25%     424.000000    1262.500000            2006-01-17 18:06:56
# 50%     474.000000    4454.000000            2010-03-29 03:16:04
# 75%     477.000000   39263.000000     2017-06-26 05:59:25.500000
# max     610.000000  193565.000000            2018-09-16 11:50:03
# std     158.472553   43490.558803                            NaN
