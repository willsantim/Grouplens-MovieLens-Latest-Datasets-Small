# %% [markdown]
# <a href="https://colab.research.google.com/github/willsantim/Grouplens-MovieLens-Latest-Datasets-Small/blob/main/Analysis_ratings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **WILLIAM SANTIM** - RA: **082220033**
# CURSO: **ENGENHARIA DE COMPUTAÇÃO**
#
# ELETIVA II - AMBIENTES INTELIGENTES
# ATIVIDADE N1 - 1° BIMESTRE
#
# **ANÁLISE DA TABELA: RATINGS**

# %% [markdown]
# IMPORTANDO BIBLIOTECAS:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Explorando o Dataset
# Dataset SMALL retirado do seguinte link: https://grouplens.org/datasets/movielens/

# %% [markdown]
# 1.1 - Importando o Dataset

# %%
df = pd.read_csv('/content/ratings.csv')

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df.columns = ['ID Usuario', 'ID Filme', 'Avaliação', 'Data e Hora Avaliação']
df.head()
# Out:
#    ID Usuario  ID Filme  Avaliação  Data e Hora Avaliação
# 0           1         1        4.0              964982703
# 1           1         3        4.0              964981247
# 2           1         6        4.0              964982224
# 3           1        47        5.0              964983815
# 4           1        50        5.0              964982931

# %% [markdown]
# 1.2 - Informações básicas do dataset

# %%
print(f'O dataset possui {df.shape[0]} exemplos/amostras/linhas e {df.shape[1]} atributos/variáveis/colunas.')
# Out:
# O dataset possui 100836 exemplos/amostras/linhas e 4 atributos/variáveis/colunas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID Usuario             100836 non-null  int64
#  1   ID Filme               100836 non-null  int64
#  2   Avaliação              100836 non-null  float64
#  3   Data e Hora Avaliação  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %% [markdown]
# Corrigindo os dados da coluna "Data e Hora Avaliação"

# %%
df['Data e Hora Avaliação'] = pd.to_datetime(df['Data e Hora Avaliação'], unit='s')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID Usuario             100836 non-null  int64
#  1   ID Filme               100836 non-null  int64
#  2   Avaliação              100836 non-null  float64
#  3   Data e Hora Avaliação  100836 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 3.1 MB

# %%
df.head()
# Out:
#    ID Usuario  ID Filme  Avaliação Data e Hora Avaliação
# 0           1         1        4.0   2000-07-30 18:45:03
# 1           1         3        4.0   2000-07-30 18:20:47
# 2           1         6        4.0   2000-07-30 18:37:04
# 3           1        47        5.0   2000-07-30 19:03:35
# 4           1        50        5.0   2000-07-30 18:48:51

# %%
df.describe()
# Out:
#           ID Usuario       ID Filme      Avaliação  \
# count  100836.000000  100836.000000  100836.000000
# mean      326.127564   19435.295718       3.501557
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8122.000000       4.000000
# max       610.000000  193609.000000       5.000000
# std       182.618491   35530.987199       1.042529
#
#                Data e Hora Avaliação
# count                         100836
# mean   2008-03-19 17:01:27.368469248
# min              1996-03-29 18:36:55
# 25%              2002-04-18 09:57:46
# 50%              2007-08-02 20:31:02
# 75%       2015-07-04 07:15:44.500000
# max              2018-09-24 14:27:30
# std                              NaN
