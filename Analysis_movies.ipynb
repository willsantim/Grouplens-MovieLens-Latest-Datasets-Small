# %% [markdown]
# <a href="https://colab.research.google.com/github/willsantim/Grouplens-MovieLens-Latest-Datasets-Small/blob/main/Analysis_movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **WILLIAM SANTIM** - RA: **082220033**
# CURSO: **ENGENHARIA DE COMPUTAÇÃO**
#
# ELETIVA II - AMBIENTES INTELIGENTES
# ATIVIDADE N1 - 1° BIMESTRE
#
# **ANÁLISE DA TABELA: MOVIES**

# %% [markdown]
# IMPORTANDO BIBLIOTECAS:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Explorando o Dataset
# Dataset SMALL retirado do seguinte link: https://grouplens.org/datasets/movielens/

# %% [markdown]
# 1.1 - Importando o Dataset

# %%
df = pd.read_csv('/content/movies.csv')

# %%
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df.columns = ['ID Filme', 'Título', 'Genero']
df.head()
# Out:
#    ID Filme                              Título  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         Genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# 1.2 - Informações básicas do dataset

# %%
print(f'O dataset possui {df.shape[0]} exemplos/amostras/linhas e {df.shape[1]} atributos/variáveis/colunas.')
# Out:
# O dataset possui 9742 exemplos/amostras/linhas e 3 atributos/variáveis/colunas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID Filme  9742 non-null   int64
#  1   Título    9742 non-null   object
#  2   Genero    9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %% [markdown]
# Corrigindo os dados da coluna "Genero"

# %%
df["Genero"] = df["Genero"].str.replace('|', ' | ')

# %%
df.head()
# Out:
#    ID Filme                              Título  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                               Genero
# 0  Adventure | Animation | Children | Comedy | Fa...
# 1                     Adventure | Children | Fantasy
# 2                                   Comedy | Romance
# 3                           Comedy | Drama | Romance
# 4                                             Comedy

# %%
df.describe()
# Out:
#             ID Filme
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000
