# %% [markdown]
# <a href="https://colab.research.google.com/github/willsantim/Grouplens-MovieLens-Latest-Datasets-Small/blob/main/Analysis_links.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **WILLIAM SANTIM** - RA: **082220033**
# CURSO: **ENGENHARIA DE COMPUTAÇÃO**
#
# ELETIVA II - AMBIENTES INTELIGENTES
# ATIVIDADE N1 - 1° BIMESTRE
#
# **ANÁLISE DA TABELA: LINKS**

# %% [markdown]
# IMPORTANDO BIBLIOTECAS:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Explorando o Dataset
#
# Dataset SMALL retirado do seguinte link: https://grouplens.org/datasets/movielens/

# %% [markdown]
# 1.1 - Importando o Dataset

# %%
df = pd.read_csv('/content/links.csv')

# %%
df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df.columns = ['ID Filme', 'ID Imdb', 'ID Tmdb']
df.head()
# Out:
#    ID Filme  ID Imdb  ID Tmdb
# 0         1   114709    862.0
# 1         2   113497   8844.0
# 2         3   113228  15602.0
# 3         4   114885  31357.0
# 4         5   113041  11862.0

# %% [markdown]
# 1.2 - Informações básicas do dataset

# %%
print(f'O dataset possui {df.shape[0]} exemplos/amostras/linhas e {df.shape[1]} atributos/variáveis/colunas.')
# Out:
# O dataset possui 9742 exemplos/amostras/linhas e 3 atributos/variáveis/colunas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID Filme  9742 non-null   int64
#  1   ID Imdb   9742 non-null   int64
#  2   ID Tmdb   9734 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 228.5 KB

# %% [markdown]
# Corrigindo os dados da coluna "ID Tmdb"

# %%
df["ID Tmdb"] = df["ID Tmdb"].fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID Filme  9742 non-null   int64
#  1   ID Imdb   9742 non-null   int64
#  2   ID Tmdb   9742 non-null   int64
# dtypes: int64(3)
# memory usage: 228.5 KB

# %%
df.describe()
# Out:
#             ID Filme       ID Imdb        ID Tmdb
# count    9742.000000  9.742000e+03    9742.000000
# mean    42200.353623  6.771839e+05   55116.825395
# std     52160.494854  1.107228e+06   93628.351521
# min         1.000000  4.170000e+02       0.000000
# 25%      3248.250000  9.518075e+04    9656.750000
# 50%      7300.000000  1.672605e+05   16497.500000
# 75%     76232.000000  8.055685e+05   44147.750000
# max    193609.000000  8.391976e+06  525662.000000
